# %% [markdown]
# # Preparing Environment

# %%
# %pip install openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in /home/helen/.local/lib/python3.10/site-packages (1.14.1)
# Requirement already satisfied: sniffio in /home/helen/.local/lib/python3.10/site-packages (from openai) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/helen/.local/lib/python3.10/site-packages (from openai) (4.10.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/helen/.local/lib/python3.10/site-packages (from openai) (0.27.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/helen/.local/lib/python3.10/site-packages (from openai) (1.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/helen/.local/lib/python3.10/site-packages (from openai) (2.6.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/helen/.local/lib/python3.10/site-packages (from openai) (4.3.0)
# Requirement already satisfied: tqdm>4 in /home/helen/.local/lib/python3.10/site-packages (from openai) (4.66.2)
# Requirement already satisfied: idna>=2.8 in /home/helen/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (3.6)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/helen/.local/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai) (1.2.0)
# Requirement already satisfied: httpcore==1.* in /home/helen/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (1.0.4)
# Requirement already satisfied: certifi in /home/helen/.local/lib/python3.10/site-packages (from httpx<1,>=0.23.0->openai) (2023.11.17)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/helen/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/helen/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (2.16.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/helen/.local/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import time
from openai import OpenAI
import os
import json

# %% [markdown]
# # Clients Setup

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=""
)

# %% [markdown]
# # Get compressed prompts

# %%
def read_json_files(folder_path):
    json_dicts = []
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.json'):
            file_path = os.path.join(folder_path, file_name)
            with open(file_path, 'r') as file:
                json_dict = json.load(file)
                json_dicts.append(json_dict)
    return json_dicts

prompts = read_json_files('./compressed_prompts_v2')

# %% [markdown]
# # Sending all prompts to GPT 3.5 Turbo

# %%
def get_completion(prompt):
    messages = [
        {"role": "user", "content": prompt['compressed_prompt']},
    ]

    start_time = time.time()
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=0,
        n=1,
        stream=False,
    )
    end_time = time.time()
    elapsed_time = end_time - start_time

    content = response.choices[0].message.content
    content_json = json.loads(content)

    return {
        **prompt,
        'response': content_json,
        'response_elapsed_time': elapsed_time
    }

# %%
time_all = 0
sessions_with_error = []

for prompt in prompts:
    if "id_session" not in prompt:
        print("Prompt without id_session")
        print("=-=-=-=-=-=-=")
        continue

    # check if file exists
    if os.path.exists(f'./responses_v2/{prompt["id_session"]}.json'):
        print(f"Prompt {prompt['id_session']} already processed")
        print("=-=-=-=-=-=-=")
        continue

    print(f"Processing prompt {prompt['id_session']}")
    try:
        response_json = get_completion(prompt)
    except Exception as e:
        sessions_with_error.append(prompt['id_session'])

        print(f"Error processing prompt {prompt['id_session']}")
        print(e)
        print("=-=-=-=-=-=-=")
        continue

    elapsed_time = response_json['response_elapsed_time']
    time_all += elapsed_time

    with open(f'./responses_v2/{prompt["id_session"]}.json', 'w') as file:
        json.dump(response_json, file)
    
    print(f"Processed prompt {prompt['id_session']} in {int(elapsed_time)} seconds")
    print("=-=-=-=-=-=-=")
    time.sleep(10)


print(f"Processed all prompts in {int(time_all)} seconds")
#save in a file the time it took to process all the prompts
with open(f'./responses_v2/processing_time.json', 'w') as file:
    json.dump({
        'processing_time': time_all
    }, file)

# Save in a file the sessions that had an error
with open(f'./responses_v2/sessions_with_error.json', 'w') as file:
    json.dump({
        'sessions_with_error': sessions_with_error
    }, file)
# Out:
# Prompt 25822 already processed
# =-=-=-=-=-=-=
# Prompt 25599 already processed
# =-=-=-=-=-=-=
# Prompt 25923 already processed
# =-=-=-=-=-=-=
# Prompt 25871 already processed
# =-=-=-=-=-=-=
# Prompt 25426 already processed
# =-=-=-=-=-=-=
# Prompt 25927 already processed
# =-=-=-=-=-=-=
# Prompt 25866 already processed
# =-=-=-=-=-=-=
# Prompt 25679 already processed
# =-=-=-=-=-=-=
# Prompt 25513 already processed
# =-=-=-=-=-=-=
# Prompt 25367 already processed
# =-=-=-=-=-=-=
# Prompt 25784 already processed
# =-=-=-=-=-=-=
# Prompt 25802 already processed
# =-=-=-=-=-=-=
# Prompt 25444 already processed
# =-=-=-=-=-=-=
# Prompt 25642 already processed
# =-=-=-=-=-=-=
# Prompt 25800 already processed
# =-=-=-=-=-=-=
# Prompt 25799 already processed
# =-=-=-=-=-=-=
# Prompt 25621 already processed
# =-=-=-=-=-=-=
# Prompt 25603 already processed
# =-=-=-=-=-=-=
# Prompt 25531 already processed
# =-=-=-=-=-=-=
# Prompt 25416 already processed
# =-=-=-=-=-=-=
# Prompt 25847 already processed
# =-=-=-=-=-=-=
# Prompt 25552 already processed
# =-=-=-=-=-=-=
# Prompt 25595 already processed
# =-=-=-=-=-=-=
# Prompt 25848 already processed
# =-=-=-=-=-=-=
# Prompt 25844 already processed
# =-=-=-=-=-=-=
# Prompt 25919 already processed
# =-=-=-=-=-=-=
# Prompt 25341 already processed
# =-=-=-=-=-=-=
# Prompt 25834 already processed
# =-=-=-=-=-=-=
# Prompt 25384 already processed
# =-=-=-=-=-=-=
# Prompt 25870 already processed
# =-=-=-=-=-=-=
# Prompt 25523 already processed
# =-=-=-=-=-=-=
# Prompt 25388 already processed
# =-=-=-=-=-=-=
# Prompt 25490 already processed
# =-=-=-=-=-=-=
# Prompt 25633 already processed
# =-=-=-=-=-=-=
# Prompt 25409 already processed
# =-=-=-=-=-=-=
# Prompt 25537 already processed
# =-=-=-=-=-=-=
# Prompt 25765 already processed
# =-=-=-=-=-=-=
# Prompt 25422 already processed
# =-=-=-=-=-=-=
# Prompt 25441 already processed
# =-=-=-=-=-=-=
# Prompt 25606 already processed
# =-=-=-=-=-=-=
# Prompt 25895 already processed
# =-=-=-=-=-=-=
# Prompt 25649 already processed
# =-=-=-=-=-=-=
# Prompt 25503 already processed
# =-=-=-=-=-=-=
# Prompt 25823 already processed
# =-=-=-=-=-=-=
# Prompt 25389 already processed
# =-=-=-=-=-=-=
# Prompt 25754 already processed
# =-=-=-=-=-=-=
# Prompt 25836 already processed
# =-=-=-=-=-=-=
# Prompt 25770 already processed
# =-=-=-=-=-=-=
# Prompt 25685 already processed
# =-=-=-=-=-=-=
# Prompt 25925 already processed
# =-=-=-=-=-=-=
# Prompt 25876 already processed
# =-=-=-=-=-=-=
# Prompt 25449 already processed
# =-=-=-=-=-=-=
# Prompt 25833 already processed
# =-=-=-=-=-=-=
# Prompt 25811 already processed
# =-=-=-=-=-=-=
# Prompt 25373 already processed
# =-=-=-=-=-=-=
# Prompt 25926 already processed
# =-=-=-=-=-=-=
# Prompt 25400 already processed
# =-=-=-=-=-=-=
# Prompt 25643 already processed
# =-=-=-=-=-=-=
# Prompt 25629 already processed
# =-=-=-=-=-=-=
# Prompt 25533 already processed
# =-=-=-=-=-=-=
# Prompt 25743 already processed
# =-=-=-=-=-=-=
# Prompt 25559 already processed
# =-=-=-=-=-=-=
# Prompt 25517 already processed
# =-=-=-=-=-=-=
# Prompt 25647 already processed
# =-=-=-=-=-=-=
# Prompt 25514 already processed
# =-=-=-=-=-=-=
# Prompt 25684 already processed
# =-=-=-=-=-=-=
# Processing prompt 25786
# Error processing prompt 25786
# Unterminated string starting at: line 239 column 13 (char 11320)
# =-=-=-=-=-=-=
# Prompt 25334 already processed
# =-=-=-=-=-=-=
# Processing prompt 25596
# Processed prompt 25596 in 7 seconds
# =-=-=-=-=-=-=
# Prompt 25751 already processed
# =-=-=-=-=-=-=
# Prompt 25532 already processed
# =-=-=-=-=-=-=
# Prompt 25555 already processed
# =-=-=-=-=-=-=
# Prompt 25471 already processed
# =-=-=-=-=-=-=
# Prompt 25763 already processed
# =-=-=-=-=-=-=
# Prompt 25670 already processed
# =-=-=-=-=-=-=
# Prompt 25605 already processed
# =-=-=-=-=-=-=
# Prompt 25767 already processed
# =-=-=-=-=-=-=
# Prompt 25745 already processed
# =-=-=-=-=-=-=
# Prompt 25674 already processed
# =-=-=-=-=-=-=
# Prompt 25653 already processed
# =-=-=-=-=-=-=
# Prompt 25453 already processed
# =-=-=-=-=-=-=
# Prompt 25544 already processed
# =-=-=-=-=-=-=
# Prompt 25512 already processed
# =-=-=-=-=-=-=
# Prompt 25398 already processed
# =-=-=-=-=-=-=
# Prompt 25568 already processed
# =-=-=-=-=-=-=
# Prompt 25742 already processed
# =-=-=-=-=-=-=
# Prompt 25761 already processed
# =-=-=-=-=-=-=
# Prompt 25353 already processed
# =-=-=-=-=-=-=
# Prompt 25600 already processed
# =-=-=-=-=-=-=
# Prompt 25835 already processed
# =-=-=-=-=-=-=
# Prompt 25627 already processed
# =-=-=-=-=-=-=
# Prompt 25597 already processed
# =-=-=-=-=-=-=
# Prompt 25867 already processed
# =-=-=-=-=-=-=
# Prompt 25430 already processed
# =-=-=-=-=-=-=
# Prompt 25435 already processed
# =-=-=-=-=-=-=
# Prompt 25651 already processed
# =-=-=-=-=-=-=
# Prompt 25386 already processed
# =-=-=-=-=-=-=
# Prompt 25397 already processed
# =-=-=-=-=-=-=
# Prompt 25407 already processed
# =-=-=-=-=-=-=
# Prompt 25624 already processed
# =-=-=-=-=-=-=
# Prompt 25346 already processed
# =-=-=-=-=-=-=
# Prompt 25872 already processed
# =-=-=-=-=-=-=
# Prompt 25628 already processed
# =-=-=-=-=-=-=
# Prompt 25432 already processed
# =-=-=-=-=-=-=
# Prompt 25521 already processed
# =-=-=-=-=-=-=
# Prompt 25378 already processed
# =-=-=-=-=-=-=
# Prompt 25638 already processed
# =-=-=-=-=-=-=
# Prompt 25395 already processed
# =-=-=-=-=-=-=
# Prompt 25355 already processed
# =-=-=-=-=-=-=
# Prompt 25399 already processed
# =-=-=-=-=-=-=
# Prompt 25689 already processed
# =-=-=-=-=-=-=
# Prompt 25794 already processed
# =-=-=-=-=-=-=
# Prompt 25480 already processed
# =-=-=-=-=-=-=
# Prompt 25617 already processed
# =-=-=-=-=-=-=
# Prompt 25547 already processed
# =-=-=-=-=-=-=
# Prompt 25630 already processed
# =-=-=-=-=-=-=
# Prompt 25641 already processed
# =-=-=-=-=-=-=
# Prompt 25690 already processed
# =-=-=-=-=-=-=
# Prompt 25893 already processed
# =-=-=-=-=-=-=
# Prompt 25672 already processed
# =-=-=-=-=-=-=
# Prompt 25682 already processed
# =-=-=-=-=-=-=
# Prompt 25884 already processed
# =-=-=-=-=-=-=
# Prompt 25496 already processed
# =-=-=-=-=-=-=
# Prompt 25644 already processed
# =-=-=-=-=-=-=
# Prompt 25675 already processed
# =-=-=-=-=-=-=
# Prompt 25445 already processed
# =-=-=-=-=-=-=
# Prompt 25456 already processed
# =-=-=-=-=-=-=
# Prompt 25798 already processed
# =-=-=-=-=-=-=
# Prompt 25508 already processed
# =-=-=-=-=-=-=
# Processing prompt 25877
# Processed prompt 25877 in 8 seconds
# =-=-=-=-=-=-=
# Prompt 25865 already processed
# =-=-=-=-=-=-=
# Prompt 25636 already processed
# =-=-=-=-=-=-=
# Prompt 25678 already processed
# =-=-=-=-=-=-=
# Prompt 25614 already processed
# =-=-=-=-=-=-=
# Prompt 25481 already processed
# =-=-=-=-=-=-=
# Prompt 25631 already processed
# =-=-=-=-=-=-=
# Prompt 25843 already processed
# =-=-=-=-=-=-=
# Prompt 25637 already processed
# =-=-=-=-=-=-=
# Prompt 25793 already processed
# =-=-=-=-=-=-=
# Prompt 25529 already processed
# =-=-=-=-=-=-=
# Prompt 25417 already processed
# =-=-=-=-=-=-=
# Prompt 25509 already processed
# =-=-=-=-=-=-=
# Prompt 25567 already processed
# =-=-=-=-=-=-=
# Prompt 25479 already processed
# =-=-=-=-=-=-=
# Prompt 25526 already processed
# =-=-=-=-=-=-=
# Prompt 25442 already processed
# =-=-=-=-=-=-=
# Prompt 25528 already processed
# =-=-=-=-=-=-=
# Prompt 25602 already processed
# =-=-=-=-=-=-=
# Prompt 25530 already processed
# =-=-=-=-=-=-=
# Prompt 25652 already processed
# =-=-=-=-=-=-=
# Prompt 25460 already processed
# =-=-=-=-=-=-=
# Prompt 25795 already processed
# =-=-=-=-=-=-=
# Prompt 25648 already processed
# =-=-=-=-=-=-=
# Prompt 25772 already processed
# =-=-=-=-=-=-=
# Prompt 25611 already processed
# =-=-=-=-=-=-=
# Prompt 25750 already processed
# =-=-=-=-=-=-=
# Prompt 25669 already processed
# =-=-=-=-=-=-=
# Prompt 25550 already processed
# =-=-=-=-=-=-=
# Prompt 25504 already processed
# =-=-=-=-=-=-=
# Prompt 25746 already processed
# =-=-=-=-=-=-=
# Prompt 25894 already processed
# =-=-=-=-=-=-=
# Prompt 25896 already processed
# =-=-=-=-=-=-=
# Prompt 25467 already processed
# =-=-=-=-=-=-=
# Prompt 25789 already processed
# =-=-=-=-=-=-=
# Prompt 25495 already processed
# =-=-=-=-=-=-=
# Prompt 25536 already processed
# =-=-=-=-=-=-=
# Prompt 25688 already processed
# =-=-=-=-=-=-=
# Prompt 25680 already processed
# =-=-=-=-=-=-=
# Prompt 25875 already processed
# =-=-=-=-=-=-=
# Prompt 25744 already processed
# =-=-=-=-=-=-=
# Prompt 25756 already processed
# =-=-=-=-=-=-=
# Prompt without id_session
# =-=-=-=-=-=-=
# Processing prompt 25507
# Processed prompt 25507 in 7 seconds
# =-=-=-=-=-=-=
# Processing prompt 25455
# Processed prompt 25455 in 7 seconds
# =-=-=-=-=-=-=
# Processing prompt 25383
# Processed prompt 25383 in 7 seconds
# =-=-=-=-=-=-=
# Processing prompt 25632
# Processed prompt 25632 in 23 seconds
# =-=-=-=-=-=-=
# Processing prompt 25527
# Processed prompt 25527 in 31 seconds
# =-=-=-=-=-=-=
# Processing prompt 25538
# Processed prompt 25538 in 7 seconds
# =-=-=-=-=-=-=
# Processing prompt 25785
# Processed prompt 25785 in 32 seconds
# =-=-=-=-=-=-=
# Processing prompt 25418
# Processed prompt 25418 in 7 seconds
# =-=-=-=-=-=-=
# Processing prompt 25406
# Processed prompt 25406 in 13 seconds
# =-=-=-=-=-=-=
# Processing prompt 25681
# Processed prompt 25681 in 6 seconds
# =-=-=-=-=-=-=
# Processing prompt 25566
# Processed prompt 25566 in 13 seconds
# =-=-=-=-=-=-=
# Processing prompt 25598
# Processed prompt 25598 in 8 seconds
# =-=-=-=-=-=-=
# Processing prompt 25419
# Processed prompt 25419 in 19 seconds
# =-=-=-=-=-=-=
# Processing prompt 25518
# Processed prompt 25518 in 45 seconds
# =-=-=-=-=-=-=
# Processing prompt 25502
# Processed prompt 25502 in 9 seconds
# =-=-=-=-=-=-=
# Processing prompt 25443
# Processed prompt 25443 in 6 seconds
# =-=-=-=-=-=-=
# Processing prompt 25755
# Processed prompt 25755 in 8 seconds
# =-=-=-=-=-=-=
# Processing prompt 25408
# Processed prompt 25408 in 11 seconds
# =-=-=-=-=-=-=
# Processing prompt 25774
# Processed prompt 25774 in 19 seconds
# =-=-=-=-=-=-=
# Processing prompt 25345
# Processed prompt 25345 in 26 seconds
# =-=-=-=-=-=-=
# Processing prompt 25760
# Processed prompt 25760 in 6 seconds
# =-=-=-=-=-=-=
# Processing prompt 25347
# Processed prompt 25347 in 14 seconds
# =-=-=-=-=-=-=
# Processing prompt 25759
# Processed prompt 25759 in 6 seconds
# =-=-=-=-=-=-=
# Processing prompt 25515
# Processed prompt 25515 in 8 seconds
# =-=-=-=-=-=-=
# Processing prompt 25519
# Error processing prompt 25519
# Unterminated string starting at: line 238 column 38 (char 11266)
# =-=-=-=-=-=-=
# Processing prompt 25886
# Processed prompt 25886 in 7 seconds
# =-=-=-=-=-=-=
# Processing prompt 25464
# Processed prompt 25464 in 4 seconds
# =-=-=-=-=-=-=
# Processing prompt 25821
# Processed prompt 25821 in 12 seconds
# =-=-=-=-=-=-=
# Processing prompt 25790
# Processed prompt 25790 in 5 seconds
# =-=-=-=-=-=-=
# Processing prompt 25782
# Processed prompt 25782 in 5 seconds
# =-=-=-=-=-=-=
# Processing prompt 25764
# Processed prompt 25764 in 10 seconds
# =-=-=-=-=-=-=
# Processing prompt 25818
# Processed prompt 25818 in 6 seconds
# =-=-=-=-=-=-=
# Processed all prompts in 418 seconds
