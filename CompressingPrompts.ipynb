# %% [markdown]
# # Preparing Environment

# %%
# %env PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True
# Out:
# env: PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True

# %%
# Install dependencies.
# !pip install llmlingua openai==1.14.1 optimum auto-gptq
# Out:
# Requirement already satisfied: llmlingua in /home/helen/anaconda3/lib/python3.9/site-packages (0.2.1)
# Requirement already satisfied: openai==1.14.1 in /home/helen/anaconda3/lib/python3.9/site-packages (1.14.1)
# Requirement already satisfied: optimum in /home/helen/anaconda3/lib/python3.9/site-packages (1.18.0)
# Requirement already satisfied: auto-gptq in /home/helen/anaconda3/lib/python3.9/site-packages (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from openai==1.14.1) (2.6.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /home/helen/anaconda3/lib/python3.9/site-packages (from openai==1.14.1) (4.10.0)
# Requirement already satisfied: sniffio in /home/helen/anaconda3/lib/python3.9/site-packages (from openai==1.14.1) (1.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from openai==1.14.1) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from openai==1.14.1) (1.9.0)
# Requirement already satisfied: tqdm>4 in /home/helen/anaconda3/lib/python3.9/site-packages (from openai==1.14.1) (4.64.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from openai==1.14.1) (0.27.0)
# Requirement already satisfied: accelerate in /home/helen/anaconda3/lib/python3.9/site-packages (from llmlingua) (0.28.0)
# Requirement already satisfied: tiktoken in /home/helen/anaconda3/lib/python3.9/site-packages (from llmlingua) (0.6.0)
# Requirement already satisfied: torch in /home/helen/anaconda3/lib/python3.9/site-packages (from llmlingua) (2.2.2)
# Requirement already satisfied: transformers>=4.26.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from llmlingua) (4.39.2)
# Requirement already satisfied: nltk in /home/helen/anaconda3/lib/python3.9/site-packages (from llmlingua) (3.7)
# Requirement already satisfied: numpy in /home/helen/anaconda3/lib/python3.9/site-packages (from llmlingua) (1.21.5)
# Requirement already satisfied: packaging in /home/helen/anaconda3/lib/python3.9/site-packages (from optimum) (21.3)
# Requirement already satisfied: datasets in /home/helen/anaconda3/lib/python3.9/site-packages (from optimum) (2.18.0)
# Requirement already satisfied: coloredlogs in /home/helen/anaconda3/lib/python3.9/site-packages (from optimum) (15.0.1)
# Requirement already satisfied: huggingface-hub>=0.8.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from optimum) (0.22.1)
# Requirement already satisfied: sympy in /home/helen/anaconda3/lib/python3.9/site-packages (from optimum) (1.10.1)
# Requirement already satisfied: sentencepiece in /home/helen/anaconda3/lib/python3.9/site-packages (from auto-gptq) (0.2.0)
# Requirement already satisfied: peft>=0.5.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from auto-gptq) (0.10.0)
# Requirement already satisfied: gekko in /home/helen/anaconda3/lib/python3.9/site-packages (from auto-gptq) (1.1.0)
# Requirement already satisfied: safetensors in /home/helen/anaconda3/lib/python3.9/site-packages (from auto-gptq) (0.4.2)
# Requirement already satisfied: rouge in /home/helen/anaconda3/lib/python3.9/site-packages (from auto-gptq) (1.0.1)
# Requirement already satisfied: psutil in /home/helen/anaconda3/lib/python3.9/site-packages (from accelerate->llmlingua) (5.9.0)
# Requirement already satisfied: pyyaml in /home/helen/anaconda3/lib/python3.9/site-packages (from accelerate->llmlingua) (6.0)
# Requirement already satisfied: idna>=2.8 in /home/helen/anaconda3/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai==1.14.1) (3.3)
# Requirement already satisfied: certifi in /home/helen/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai==1.14.1) (2022.9.14)
# Requirement already satisfied: httpcore==1.* in /home/helen/anaconda3/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai==1.14.1) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/helen/anaconda3/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.14.1) (0.14.0)
# Requirement already satisfied: requests in /home/helen/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.8.0->optimum) (2.28.1)
# Requirement already satisfied: filelock in /home/helen/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.8.0->optimum) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from huggingface-hub>=0.8.0->optimum) (2024.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/helen/anaconda3/lib/python3.9/site-packages (from packaging->optimum) (3.0.9)
# Requirement already satisfied: pydantic-core==2.16.3 in /home/helen/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai==1.14.1) (2.16.3)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai==1.14.1) (0.6.0)
# Requirement already satisfied: triton==2.2.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (2.2.0)
# Requirement already satisfied: jinja2 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (2.11.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (12.1.105)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (12.1.0.106)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (12.1.105)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (12.1.105)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (12.1.105)
# Requirement already satisfied: networkx in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (2.8.4)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (2.19.3)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (11.0.2.54)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (12.1.3.1)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (8.9.2.26)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (11.4.5.107)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/helen/anaconda3/lib/python3.9/site-packages (from torch->llmlingua) (10.3.2.106)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/helen/anaconda3/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->llmlingua) (12.4.99)
# Requirement already satisfied: regex!=2019.12.17 in /home/helen/anaconda3/lib/python3.9/site-packages (from transformers>=4.26.0->llmlingua) (2022.7.9)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/helen/anaconda3/lib/python3.9/site-packages (from transformers>=4.26.0->llmlingua) (0.15.2)
# Requirement already satisfied: protobuf in /home/helen/anaconda3/lib/python3.9/site-packages (from transformers>=4.26.0->llmlingua) (5.26.1)
# Requirement already satisfied: humanfriendly>=9.1 in /home/helen/anaconda3/lib/python3.9/site-packages (from coloredlogs->optimum) (10.0)
# Requirement already satisfied: pyarrow-hotfix in /home/helen/anaconda3/lib/python3.9/site-packages (from datasets->optimum) (0.6)
# Requirement already satisfied: multiprocess in /home/helen/anaconda3/lib/python3.9/site-packages (from datasets->optimum) (0.70.16)
# Requirement already satisfied: pandas in /home/helen/anaconda3/lib/python3.9/site-packages (from datasets->optimum) (1.4.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from datasets->optimum) (15.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from datasets->optimum) (0.3.8)
# Requirement already satisfied: xxhash in /home/helen/anaconda3/lib/python3.9/site-packages (from datasets->optimum) (3.4.1)
# Requirement already satisfied: aiohttp in /home/helen/anaconda3/lib/python3.9/site-packages (from datasets->optimum) (3.9.3)
# Requirement already satisfied: joblib in /home/helen/anaconda3/lib/python3.9/site-packages (from nltk->llmlingua) (1.1.0)
# Requirement already satisfied: click in /home/helen/anaconda3/lib/python3.9/site-packages (from nltk->llmlingua) (8.0.4)
# Requirement already satisfied: six in /home/helen/anaconda3/lib/python3.9/site-packages (from rouge->auto-gptq) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /home/helen/anaconda3/lib/python3.9/site-packages (from sympy->optimum) (1.2.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/helen/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets->optimum) (6.0.5)
# Requirement already satisfied: attrs>=17.3.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets->optimum) (21.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/helen/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets->optimum) (1.4.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets->optimum) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/helen/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets->optimum) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/helen/anaconda3/lib/python3.9/site-packages (from aiohttp->datasets->optimum) (4.0.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/helen/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/helen/anaconda3/lib/python3.9/site-packages (from requests->huggingface-hub>=0.8.0->optimum) (1.26.11)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/helen/anaconda3/lib/python3.9/site-packages (from jinja2->torch->llmlingua) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/helen/anaconda3/lib/python3.9/site-packages (from pandas->datasets->optimum) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/helen/anaconda3/lib/python3.9/site-packages (from pandas->datasets->optimum) (2022.1)

# %%
import json
import time
from openai import OpenAI
import pandas as pd

# %% [markdown]
# # Clients Setup

# %%
client = OpenAI(
    # This is the default and can be omitted
    api_key=""
)

# %%
# Setup LLMLingua
from llmlingua import PromptCompressor

llm_lingua = PromptCompressor("TheBloke/Llama-2-7b-Chat-GPTQ", model_config={"revision": "main"})
# Out:
# /home/helen/anaconda3/lib/python3.9/site-packages/transformers/modeling_utils.py:4225: FutureWarning: `_is_quantized_training_enabled` is going to be deprecated in transformers 4.39.0. Please use `model.hf_quantizer.is_trainable` instead
#   warnings.warn(
# The cos_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class
# The sin_cached attribute will be removed in 4.39. Bear in mind that its contents changed in v4.38. Use the forward method of RoPE from now on instead. It is not used in the `LlamaAttention` class

# %% [markdown]
# # Normalize Dataframe

# %%
meetings_df = pd.read_csv('./meetings.csv')
# FILTERING BY SESSION 25355
# meetings_df = meetings_df[meetings_df["id_session"] == 25345]

# %%
def transform_df_to_speeches_list(text_df):
    speakers = text_df['speaker_name']
    speeches = text_df['speech']
    
    speeches_list = ""
    for index, _ in enumerate(speakers.iteritems()):
        speeches_list += f"<llmlingua, compress=False>{speakers.iloc[index]}</llmlingua>: {speeches.iloc[index]}\n"
    return speeches_list

def get_speakers_list_from_dataframe(df):
    return list(set(df['speaker_name']))

# %% [markdown]
# # Prompt

# %%
def summarization_prompt_for_stances(context: str, dataframe):
    speakers_list = get_speakers_list_from_dataframe(dataframe)
    speakers_string = ', '.join(speakers_list)
    
    prompt = f"""
    Consider that it is an expert model in Stance Detection. Stance detection is the task of predicting an author's point of view on a subject of interest. A speech can represent one of four types of stance: for, against or neutral.
For: When an author takes a stance "for" a subject, it means they support or advocate for it. Their speech or writing will likely include arguments, evidence, or opinions that highlight the positive aspects, benefits, or reasons to endorse the subject. For example, if the subject is a proposed policy change, someone taking a "for" stance might emphasize how it could improve people's lives or address important societal issues.
Against: This stance indicates opposition or disagreement with the subject at hand. Authors taking an "against" stance will present arguments, evidence, or opinions that highlight flaws, risks, negative consequences, or reasons to reject the subject. Using the previous example of a proposed policy change, someone taking an "against" stance might argue that it would be ineffective, unfair, or harmful to certain groups.
Neutral: A neutral stance means the author does not express explicit support or opposition towards the subject. They may present information, analysis, or perspectives in a balanced and objective manner without advocating for or against the subject. Neutral stances typically avoid strong opinions or judgments and instead focus on providing a comprehensive understanding of the topic without bias. If the person doesn't say anything about that topic, it means that they should not be listed.
Reply in json format with the following keys: list_latent_topics, stances and summary.
list_latent_topics: should contain the list of all topics discussed in the text, and a short description for each topic.
stances: for each latent_topics key should contain the list of classification of the related speaker's speechs.
summary: should contain the summary of the text.
    Consider that you will receive as input a text with a set of speeches that make up ```{context}```.

    Do the following actions for the text:
    - Determine the all topics being discussed in the text and a brief descriptions of these topics.
    - For each topic and for each speaker, except if the person doesn't say anything about that topic, classify the stance as being FOR, AGAINST, NEUTRAL. Being the following speakers: {speakers_string}.
    - Before your response, translate the summary and the topics to portuguese.
   """
    return prompt

# %% [markdown]
# # Compressing

# %%
def compress_prompt_for_df(id_session: int, dataframe):
    start_time = time.time()
    
    TARGET_TOKEN = 8000
    speeches_list = transform_df_to_speeches_list(dataframe)
    prompt = summarization_prompt_for_stances('parliamentary session', dataframe)
    
    compressed_prompt = llm_lingua.compress_prompt(
        speeches_list.split("\n"),
        instruction="",
        question=prompt,
        target_token=TARGET_TOKEN,
        condition_compare=True,
        condition_in_question="after",
        rank_method="longllmlingua",
        use_sentence_level_filter=False,
        context_budget="+100",
        dynamic_context_compression_ratio=0.4,  # enable dynamic_context_compression_ratio
        reorder_context="sort",
    )
    
    end_time = time.time()
    elapsed_time = end_time - start_time
    
    return {
        "id_session": int(id_session),
        "elapsed_time": float(elapsed_time),
        **compressed_prompt
    }

# %% [markdown]
# # Compressing all sessions

# %%
# SLICE TO NOT START FROM THE BEGINNING
id_sessions = meetings_df["id_session"].unique()

total = len(id_sessions)
start_time = time.time()

ignored_sessions = []

for index, id_session in enumerate(id_sessions):
    print(f'Session {id_session} started!')
    session_df = meetings_df[meetings_df["id_session"] == id_session]
    
    if session_df["speaker_name"].isnull().values.all():
        print(f'Session {id_session} ignored!')
        ignored_sessions.append(id_session)
        print('=-=-=-=-=')
        continue
    
    response = compress_prompt_for_df(id_session, session_df)
    
    with open(f'./compressed_prompts/{id_session}.json', 'w') as file:
        file.write(json.dumps(response, indent=4))
        
    end_time = time.time()
    elapsed_time = end_time - start_time
    
    print(f'Session {id_session} compressed!')
    print(f'{index + 1} / {total} completed!')
    print(f'{elapsed_time} seconds elapsed!')
    print('=-=-=-=-=')

with open('./ignored_sessions.json', 'w') as file:
    file.write(json.dumps({ "sessions": ignored_sessions }, indent=4))
# Out:
# Session 25779 started!
# Session 25779 ignored!
# =-=-=-=-=
# Session 25568 started!
# Session 25568 compressed!
# 2 / 84 completed!
# 87.54777073860168 seconds elapsed!
# =-=-=-=-=
# Session 25595 started!
# Session 25595 compressed!
# 3 / 84 completed!
# 153.2989625930786 seconds elapsed!
# =-=-=-=-=
# Session 25624 started!
# Session 25624 compressed!
# 4 / 84 completed!
# 184.65553331375122 seconds elapsed!
# =-=-=-=-=
# Session 25772 started!
# Session 25772 compressed!
# 5 / 84 completed!
# 263.40307784080505 seconds elapsed!
# =-=-=-=-=
# Session 25647 started!
# Session 25647 compressed!
# 6 / 84 completed!
# 352.16352581977844 seconds elapsed!
# =-=-=-=-=
# Session 25648 started!
# Session 25648 compressed!
# 7 / 84 completed!
# 525.7481753826141 seconds elapsed!
# =-=-=-=-=
# Session 25649 started!
# Session 25649 compressed!
# 8 / 84 completed!
# 567.0071823596954 seconds elapsed!
# =-=-=-=-=
# Session 25621 started!
# Session 25621 compressed!
# 9 / 84 completed!
# 598.7188303470612 seconds elapsed!
# =-=-=-=-=
# Session 25674 started!
# Session 25674 compressed!
# 10 / 84 completed!
# 642.9481461048126 seconds elapsed!
# =-=-=-=-=
# Session 25675 started!
# Session 25675 compressed!
# 11 / 84 completed!
# 680.8311808109283 seconds elapsed!
# =-=-=-=-=
# Session 25559 started!
# Session 25559 compressed!
# 12 / 84 completed!
# 707.6418902873993 seconds elapsed!
# =-=-=-=-=
# Session 25678 started!
# Session 25678 compressed!
# 13 / 84 completed!
# 801.1216175556183 seconds elapsed!
# =-=-=-=-=
# Session 25679 started!
# Session 25679 compressed!
# 14 / 84 completed!
# 975.7389912605286 seconds elapsed!
# =-=-=-=-=
# Session 25680 started!
# Session 25680 compressed!
# 15 / 84 completed!
# 1085.2806718349457 seconds elapsed!
# =-=-=-=-=
# Session 25681 started!
# Session 25681 compressed!
# 16 / 84 completed!
# 1115.9583740234375 seconds elapsed!
# =-=-=-=-=
# Session 25682 started!
# Session 25682 compressed!
# 17 / 84 completed!
# 1146.2500970363617 seconds elapsed!
# =-=-=-=-=
# Session 25774 started!
# Session 25774 compressed!
# 18 / 84 completed!
# 1177.4141852855682 seconds elapsed!
# =-=-=-=-=
# Session 25651 started!
# Session 25651 compressed!
# 19 / 84 completed!
# 1227.0843575000763 seconds elapsed!
# =-=-=-=-=
# Session 25818 started!
# Session 25818 compressed!
# 20 / 84 completed!
# 1251.4606518745422 seconds elapsed!
# =-=-=-=-=
# Session 25684 started!
# Session 25684 compressed!
# 21 / 84 completed!
# 1344.70534157753 seconds elapsed!
# =-=-=-=-=
# Session 25822 started!
# Session 25822 compressed!
# 22 / 84 completed!
# 1411.305115699768 seconds elapsed!
# =-=-=-=-=
# Session 25685 started!
# Session 25685 compressed!
# 23 / 84 completed!
# 1509.8135821819305 seconds elapsed!
# =-=-=-=-=
# Session 25765 started!
# Session 25765 compressed!
# 24 / 84 completed!
# 1548.0062680244446 seconds elapsed!
# =-=-=-=-=
# Session 25688 started!
# Session 25688 compressed!
# 25 / 84 completed!
# 1589.239889383316 seconds elapsed!
# =-=-=-=-=
# Session 25689 started!
# Session 25689 compressed!
# 26 / 84 completed!
# 1676.4372498989105 seconds elapsed!
# =-=-=-=-=
# Session 25690 started!
# Session 25690 compressed!
# 27 / 84 completed!
# 1854.3028423786163 seconds elapsed!
# =-=-=-=-=
# Session 25834 started!
# Session 25834 compressed!
# 28 / 84 completed!
# 1898.1091585159302 seconds elapsed!
# =-=-=-=-=
# Session 25823 started!
# Session 25823 compressed!
# 29 / 84 completed!
# 1918.6395599842072 seconds elapsed!
# =-=-=-=-=
# Session 25745 started!
# Session 25745 compressed!
# 30 / 84 completed!
# 1971.0464825630188 seconds elapsed!
# =-=-=-=-=
# Session 25821 started!
# Session 25821 compressed!
# 31 / 84 completed!
# 1999.1867489814758 seconds elapsed!
# =-=-=-=-=
# Session 25746 started!
# Session 25746 compressed!
# 32 / 84 completed!
# 2090.231300830841 seconds elapsed!
# =-=-=-=-=
# Session 25843 started!
# Session 25843 compressed!
# 33 / 84 completed!
# 2174.7699308395386 seconds elapsed!
# =-=-=-=-=
# Session 25811 started!
# Session 25811 compressed!
# 34 / 84 completed!
# 2260.50367975235 seconds elapsed!
# =-=-=-=-=
# Session 25836 started!
# Session 25836 compressed!
# 35 / 84 completed!
# 2291.5274937152863 seconds elapsed!
# =-=-=-=-=
# Session 25750 started!
# Session 25750 compressed!
# 36 / 84 completed!
# 2333.4390890598297 seconds elapsed!
# =-=-=-=-=
# Session 25751 started!
# Session 25751 compressed!
# 37 / 84 completed!
# 2448.014835357666 seconds elapsed!
# =-=-=-=-=
# Session 25754 started!
# Session 25754 compressed!
# 38 / 84 completed!
# 2487.833194732666 seconds elapsed!
# =-=-=-=-=
# Session 25848 started!
# Session 25848 compressed!
# 39 / 84 completed!
# 2520.514691591263 seconds elapsed!
# =-=-=-=-=
# Session 25755 started!
# Session 25755 compressed!
# 40 / 84 completed!
# 2642.1014745235443 seconds elapsed!
# =-=-=-=-=
# Session 25884 started!
# Session 25884 compressed!
# 41 / 84 completed!
# 2675.8001012802124 seconds elapsed!
# =-=-=-=-=
# Session 25756 started!
# Session 25756 compressed!
# 42 / 84 completed!
# 2737.7609009742737 seconds elapsed!
# =-=-=-=-=
# Session 25894 started!
# Session 25894 compressed!
# 43 / 84 completed!
# 2777.8926000595093 seconds elapsed!
# =-=-=-=-=
# Session 25847 started!
# Session 25847 compressed!
# 44 / 84 completed!
# 2824.036844968796 seconds elapsed!
# =-=-=-=-=
# Session 25770 started!
# Session 25770 compressed!
# 45 / 84 completed!
# 2859.4029235839844 seconds elapsed!
# =-=-=-=-=
# Session 25759 started!
# Session 25759 compressed!
# 46 / 84 completed!
# 2889.1808874607086 seconds elapsed!
# =-=-=-=-=
# Session 25760 started!
# Session 25760 compressed!
# 47 / 84 completed!
# 3046.5492730140686 seconds elapsed!
# =-=-=-=-=
# Session 25893 started!
# Session 25893 compressed!
# 48 / 84 completed!
# 3078.121021270752 seconds elapsed!
# =-=-=-=-=
# Session 25761 started!
# Session 25761 compressed!
# 49 / 84 completed!
# 3198.011297225952 seconds elapsed!
# =-=-=-=-=
# Session 25835 started!
# Session 25835 compressed!
# 50 / 84 completed!
# 3254.085417985916 seconds elapsed!
# =-=-=-=-=
# Session 25844 started!
# Session 25844 compressed!
# 51 / 84 completed!
# 3280.273576259613 seconds elapsed!
# =-=-=-=-=
# Session 25763 started!
# Session 25763 compressed!
# 52 / 84 completed!
# 3311.1517884731293 seconds elapsed!
# =-=-=-=-=
# Session 25764 started!
# Session 25764 compressed!
# 53 / 84 completed!
# 3426.7040560245514 seconds elapsed!
# =-=-=-=-=
# Session 25782 started!
# Session 25782 compressed!
# 54 / 84 completed!
# 3474.995784521103 seconds elapsed!
# =-=-=-=-=
# Session 25784 started!
# Session 25784 compressed!
# 55 / 84 completed!
# 3512.1132695674896 seconds elapsed!
# =-=-=-=-=
# Session 25785 started!
# Session 25785 compressed!
# 56 / 84 completed!
# 3636.1169471740723 seconds elapsed!
# =-=-=-=-=
# Session 25786 started!
# Session 25786 compressed!
# 57 / 84 completed!
# 3875.777266263962 seconds elapsed!
# =-=-=-=-=
# Session 25896 started!
# Session 25896 compressed!
# 58 / 84 completed!
# 3920.6941266059875 seconds elapsed!
# =-=-=-=-=
# Session 25789 started!
# Session 25789 compressed!
# 59 / 84 completed!
# 3951.2505843639374 seconds elapsed!
# =-=-=-=-=
# Session 25790 started!
# Session 25790 compressed!
# 60 / 84 completed!
# 4021.9279038906097 seconds elapsed!
# =-=-=-=-=
# Session 25793 started!
# Session 25793 compressed!
# 61 / 84 completed!
# 4066.510772705078 seconds elapsed!
# =-=-=-=-=
# Session 25919 started!
# Session 25919 compressed!
# 62 / 84 completed!
# 4111.167744398117 seconds elapsed!
# =-=-=-=-=
# Session 25794 started!
# Session 25794 compressed!
# 63 / 84 completed!
# 4200.845782518387 seconds elapsed!
# =-=-=-=-=
# Session 25795 started!
# Session 25795 compressed!
# 64 / 84 completed!
# 4287.758528709412 seconds elapsed!
# =-=-=-=-=
# Session 25895 started!
# Session 25895 compressed!
# 65 / 84 completed!
# 4344.571771144867 seconds elapsed!
# =-=-=-=-=
# Session 25886 started!
# Session 25886 compressed!
# 66 / 84 completed!
# 4369.091445684433 seconds elapsed!
# =-=-=-=-=
# Session 25798 started!
# Session 25798 compressed!
# 67 / 84 completed!
# 4395.5448043346405 seconds elapsed!
# =-=-=-=-=
# Session 25799 started!
# Session 25799 compressed!
# 68 / 84 completed!
# 4508.28399181366 seconds elapsed!
# =-=-=-=-=
# Session 25800 started!
# Session 25800 compressed!
# 69 / 84 completed!
# 4647.608798265457 seconds elapsed!
# =-=-=-=-=
# Session 25802 started!
# Session 25802 compressed!
# 70 / 84 completed!
# 4677.190502405167 seconds elapsed!
# =-=-=-=-=
# Session 25926 started!
# Session 25926 compressed!
# 71 / 84 completed!
# 4702.904520511627 seconds elapsed!
# =-=-=-=-=
# Session 25927 started!
# Session 25927 compressed!
# 72 / 84 completed!
# 4730.649970769882 seconds elapsed!
# =-=-=-=-=
# Session 25865 started!
# Session 25865 compressed!
# 73 / 84 completed!
# 4758.317718505859 seconds elapsed!
# =-=-=-=-=
# Session 25866 started!
# Session 25866 compressed!
# 74 / 84 completed!
# 4848.27715921402 seconds elapsed!
# =-=-=-=-=
# Session 25867 started!
# Session 25867 compressed!
# 75 / 84 completed!
# 4913.36635351181 seconds elapsed!
# =-=-=-=-=
# Session 25923 started!
# Session 25923 compressed!
# 76 / 84 completed!
# 4944.853772640228 seconds elapsed!
# =-=-=-=-=
# Session 25870 started!
# Session 25870 compressed!
# 77 / 84 completed!
# 4984.792960882187 seconds elapsed!
# =-=-=-=-=
# Session 25871 started!
# Session 25871 compressed!
# 78 / 84 completed!
# 5226.80476474762 seconds elapsed!
# =-=-=-=-=
# Session 25925 started!
# Session 25925 compressed!
# 79 / 84 completed!
# 5251.408168077469 seconds elapsed!
# =-=-=-=-=
# Session 25872 started!
# Session 25872 compressed!
# 80 / 84 completed!
# 5353.356185674667 seconds elapsed!
# =-=-=-=-=
# Session 25833 started!
# Session 25833 compressed!
# 81 / 84 completed!
# 5391.999587535858 seconds elapsed!
# =-=-=-=-=
# Session 25875 started!
# Session 25875 compressed!
# 82 / 84 completed!
# 5423.237101793289 seconds elapsed!
# =-=-=-=-=
# Session 25876 started!
# Session 25876 compressed!
# 83 / 84 completed!
# 5496.9141590595245 seconds elapsed!
# =-=-=-=-=
# Session 25877 started!
# Session 25877 compressed!
# 84 / 84 completed!
# 5598.971356630325 seconds elapsed!
# =-=-=-=-=
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_10033/3973466926.py in <module>
#      31
#      32 with open('./ignored_sessions.json', 'w') as file:
# ---> 33     file.write(json.dumps({ "sessions": ignored_sessions }, indent=4))
#
# ~/anaconda3/lib/python3.9/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232     if cls is None:
#     233         cls = JSONEncoder
# --> 234     return cls(
#     235         skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#
# ~/anaconda3/lib/python3.9/json/encoder.py in encode(self, o)
#     199         chunks = self.iterencode(o, _one_shot=True)
#     200         if not isinstance(chunks, (list, tuple)):
# --> 201             chunks = list(chunks)
#     202         return ''.join(chunks)
#     203
#
# ~/anaconda3/lib/python3.9/json/encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# ~/anaconda3/lib/python3.9/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.9/json/encoder.py in _iterencode_list(lst, _current_indent_level)
#     323                 else:
#     324                     chunks = _iterencode(value, _current_indent_level)
# --> 325                 yield from chunks
#     326         if newline_indent is not None:
#     327             _current_indent_level -= 1
#
# ~/anaconda3/lib/python3.9/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# ~/anaconda3/lib/python3.9/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type int64 is not JSON serializable
